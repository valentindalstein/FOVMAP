# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
# %matplotlib qt

from fovmap.file_utils import parse_lens_dir_csv_file
from fovmap.manual_hex_segmentation import manual_hex_segmentation
from fovmap import FILES_PATH

# %% [markdown]
# ## Get Vertices

# %% [markdown]
# read file

# %% [markdown]
# ## Calculate Cone and vertices Intersection

# %% [markdown]
# ## Calculate Faces Deformation

# %% [markdown]
# ## Classify Faces

# %% [markdown]
# ## Handle surfaces with partial intersection

# %% [markdown]
# ## Surface Rendering per index
