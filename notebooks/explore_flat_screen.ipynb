# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
# %matplotlib qt

from fovmap.plots_utils import visualize_lens_dir, plot_cone
from fovmap.file_utils import (
    parse_lens_dir_csv_file,
    rotate_vectors,
    load_manual_hex_grid_face_list,
    create_intersect_df
    )
from fovmap.vector_cone_intersect import vector_cone_intersection
from fovmap.surface_plot import (
    plane_surface_orthogonal_center,
    plane_surface_center_tilt
    )
from fovmap.face_utils import (
    categorize_face,
    plot_hexagonal_surfaces_from_df,
    project_points_on_surface
)
from fovmap.deformation_metrics import (
    calculate_metrics
)
from fovmap.vertices_filtering import filter_vert_z_bound, filter_vert_z_bound_w_none
from fovmap import FILES_PATH, CONFIG_PATH

# %%
surface = plane_surface_orthogonal_center(
    10,
    7,
    -3.5,
    4,
    -30,
    100
)

# %%
x, y, z = surface

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
# plot a 3D surface
# create the figure
fig = plt.figure()
# create the 3D plot set the axis properly
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# ignore nan values
max_dist = max(np.nanmax(x), np.nanmax(y), np.nanmax(z))
ax.set_xlim(-max_dist, max_dist)
ax.set_ylim(-max_dist, max_dist)
ax.set_zlim(-max_dist, max_dist)
ax.set_aspect('equal')
ax.plot_surface(x, y, z, color="gray", alpha=0.25)
fig.show()

# %%
surface_2 = plane_surface_center_tilt(
    10,
    7,
    -3.5,
    4,
    -30,
    20,
    100
)

# %%
x_2, y_2, z_2 = surface_2

# %%
# plot a 3D surface
# create the figure
fig_2 = plt.figure()
# create the 3D plot set the axis properly
ax_2 = fig_2.add_subplot(111, projection='3d')
ax_2.set_xlabel('X')
ax_2.set_ylabel('Y')
ax_2.set_zlabel('Z')
# ignore nan values
max_dist_2 = max(np.nanmax(x_2), np.nanmax(y_2), np.nanmax(z_2))
ax_2.set_xlim(-max_dist_2, max_dist_2)
ax_2.set_ylim(-max_dist_2, max_dist_2)
ax_2.set_zlim(-max_dist_2, max_dist_2)
ax_2.set_aspect('equal')
ax_2.plot_surface(x_2, y_2, z_2, color="gray", alpha=0.25)
