# %%
import json

from fovmap.surface_plot import cone_surface_apex_neg_z
from fovmap.file_utils import convert_polyhedron_to_json
from fovmap import FILES_PATH, CONFIG_PATH

# %% [markdown]
# Load icosahedron

# %%
icosahedron_filename = FILES_PATH / "dual_geodesic_icosahedron_pattern_12.json"
with open(icosahedron_filename
          ) as f:
    icosahedron = json.load(f)
vertices = icosahedron["vertices"]
faces = icosahedron["faces"]

# %% [markdown]
# Load cone

# %%
config_name = "cone_config"
cone_config = json.load(open(CONFIG_PATH / f"{config_name}.json"))
cone_xyz = cone_surface_apex_neg_z(**cone_config)
cone_xyz
# Out:
# (array([[22.5897076 , 22.54422721, 22.40796917, ..., 22.40796917,
#          22.54422721, 22.5897076 ],
#         [22.88160954, 22.83554146, 22.69752271, ..., 22.69752271,
#          22.83554146, 22.88160954],
#         [23.17351149, 23.12685571, 22.98707625, ..., 22.98707625,
#          23.12685571, 23.17351149],
#         ...,
#         [50.90419611, 50.8017095 , 50.49466233, ..., 50.49466233,
#          50.8017095 , 50.90419611],
#         [51.19609806, 51.09302375, 50.78421587, ..., 50.78421587,
#          51.09302375, 51.19609806],
#         [51.488     , 51.384338  , 51.0737694 , ..., 51.0737694 ,
#          51.384338  , 51.488     ]]),
#  array([[ 0.00000000e+00,  1.43272780e+00,  2.85968651e+00, ...,
#          -2.85968651e+00, -1.43272780e+00, -5.53288262e-15],
#         [ 0.00000000e+00,  1.45124137e+00,  2.89663909e+00, ...,
#          -2.89663909e+00, -1.45124137e+00, -5.60437798e-15],
#         [ 0.00000000e+00,  1.46975493e+00,  2.93359168e+00, ...,
# ...

# %% [markdown]
# Project vertices onto cone
